# %% [markdown]
# # NIH Chest X-Ray Dataset: Dimensionality Reduction

# %% [markdown]
# ## Load Libraries

# %%
from drift_detection.utils.drift_detector_utils import ContextMMDWrapper, ContextMMDDrift

# %%
from drift_detection.drift_detector import TSTester, DCTester
import matplotlib.pyplot as plt
import numpy as np
import torch

tester = TSTester('ctx_mmd')

X_s = np.random.randn(200, 512)
X_t = X_s

p_val, dist = tester.test_shift(X_s = X_s, 
                                X_t = X_t,
                                backend='pytorch',
                                context_type='gmm',
                               )

p_val
# Out:
# 1.0

# %%
class Dog:
    def __init__(self, cat=5, backend: str = 'tensorflow',p_val: float = 0.05, preprocess_x_ref: bool = True):
        print(get_args(LearnedKernelDrift, locals()))

# %%
Dog()
# Out:
# {'self': <__main__.Dog object at 0x7f6b22eab610>, 'backend': 'tensorflow', 'p_val': 0.05, 'preprocess_x_ref': True}

# %%
import inspect

def get_args(obj, kwargs):
    '''
    Get valid arguments from kwargs to pass to object.

    Parameters
    ----------
    obj
        object to get arguments from.
    kwargs  
        Dictionary of arguments to pass to object.
    
    Returns
    -------
    args
        Dictionary of valid arguments to pass to class object.
    '''
    args = {}
    for key in kwargs:
        if inspect.isclass(obj):
            if key in obj.__init__.__code__.co_varnames:
                args[key] = kwargs[key]
        elif inspect.ismethod(obj) or inspect.isfunction(obj):
            if key in obj.__code__.co_varnames:
                args[key] = kwargs[key]
    return args

# %%
from alibi_detect.cd import LearnedKernelDrift

# %%
from alibi_detect.cd import MMDDrift

# %%
from drift_detection.drift_detector import TSTester, DCTester
import matplotlib.pyplot as plt
import numpy as np
import torch

tester = TSTester('lk')

X_s = np.random.randn(200, 64, 512)
X_t = X_s

p_val, dist = tester.test_shift(X_s = X_s,
                                X_t = X_t,
                                backend='pytorch',
                                proj_type='ffnn',
                                verbose=1,
                                epochs=100
                               )

p_val
# Out:
# ...
# Epoch 100/100: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00, 81.88it/s, loss=-.246]
# 0.9900000095367432

# %%
from drift_detection.drift_detector import DCTester
import matplotlib.pyplot as plt
import numpy as np
import torch

tester = DCTester('rf')

X_s = np.random.randn(200, 512)
X_t = X_s

p_val, dist = tester.test_shift(X_s = X_s,
                                X_t = X_t,
                                backend='sklearn',
                                verbose=1,
                               )

p_val
# Out:
# `retrain_from_scratch=True` sets automatically the parameter `warm_start=False`.
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    0.0s finished
# 1.0
