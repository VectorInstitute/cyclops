# %% [markdown]
# # Imports

# %%
import time
import pandas as pd
from cyclops.processors.clean import normalize_names, normalize_values
from cyclops.processors.column_names import (
    DISCHARGE_TIMESTAMP,
    ENCOUNTER_ID,
    EVENT_NAME,
    EVENT_VALUE,
)
from cyclops.processors.feature.split import intersect_datasets
from cyclops.utils.file import join, save_dataframe
from drift_detection.gemini.mortality.constants import (
    CLEANED_DIR,
    ENCOUNTERS_FILE,
    OUTCOME_DEATH,
    QUERIED_DIR,
    TARGET_TIMESTAMP,
)
from drift_detection.gemini.query import main
# Out:
# 2022-11-08 13:03:20,075 INFO cyclops.orm     - Database setup, ready to run queries!

# %% [markdown]
# # Query

# %%
t = time.time()
cohort, events = main()
print(time.time() - t)
cohort
# Out:
# 2022-11-08 13:03:26,162 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:03:26,167 INFO cyclops.utils.profile - Finished executing function run_query in 6.004662 s
# 2022-11-08 13:03:28,959 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:03:28,964 INFO cyclops.utils.profile - Finished executing function run_query in 2.793898 s
# 2022-11-08 13:03:49,658 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:03:49,663 INFO cyclops.utils.profile - Finished executing function run_query in 19.888311 s
# 2022-11-08 13:04:04,505 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:04:05,606 INFO cyclops.utils.profile - Finished executing function run_query in 2.988089 s
# 2022-11-08 13:04:08,146 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:04:08,150 INFO cyclops.utils.profile - Finished executing function run_query in 1.588584 s
# 2022-11-08 13:05:04,714 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:05:04,722 INFO cyclops.utils.profile - Finished executing function run_query in 56.480524 s
# 2022-11-08 13:05:22,589 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:05:22,594 INFO cyclops.utils.profile - Finished executing function run_query in 17.191827 s
# 2022-11-08 13:14:55,112 INFO cyclops.orm     - Query returned successfully!
# 2022-11-08 13:14:55,117 INFO cyclops.utils.profile - Finished executing function run_query in 570.679078 s
# 767.5443470478058
#         encounter_id     admit_timestamp discharge_timestamp  age sex  \
# 0           15320930 2017-10-22 10:30:00 2018-03-14 16:00:00   88   F
# 1           15535918 2016-08-30 12:00:00 2016-09-09 18:09:00   28   F
# 2           15612180 2014-11-12 04:11:00 2014-11-20 18:53:00   65   F
# 3           15682885 2017-04-06 05:15:00 2017-04-07 22:06:00   73   F
# 4           15712185 2012-11-14 03:30:00 2012-11-26 14:42:00   65   M
# ...              ...                 ...                 ...  ...  ..
# 143318      12349773 2020-02-11 10:15:00 2020-02-11 13:15:00   63   M
# 143319      13651026 2020-04-14 19:14:00 2020-04-27 12:15:00   95   F
# 143320      13933236 2018-12-29 20:53:00 2019-01-21 13:00:00   57   M
# 143321      15508246 2018-04-05 18:14:00 2018-04-17 18:03:00   91   M
# 143322      12748263 2020-04-13 01:51:00 2020-04-21 14:25:00   90   F
#
#        hospital_id  outcome_death         readmission  \
# 0             THPC          False                nota
# 1             THPC          False                nota
# 2             THPC          False                nota
# 3             THPC          False        new_to_acute
# 4             THPC          False        new_to_acute
# ...            ...            ...                 ...
# 143318         SBK           True  planned_from_acute
# 143319       UHNTG           True                nota
# 143320       UHNTG           True                nota
# 143321        THPM           True                nota
# 143322         SBK           True                nota
#
#         from_nursing_home_mapped  from_acute_care_institution_mapped  \
# 0                          False                               False
# 1                          False                               False
# 2                          False                               False
# 3                          False                               False
# 4                          False                               False
# ...                          ...                                 ...
# 143318                     False                               False
# 143319                     False                               False
# 143320                     False                               False
# 143321                     False                               False
# 143322                     False                               False
#
#         los_derived  prev_encounter_count diagnosis_code diagnosis_trajectory  \
# 0        143.229170                     0           I500              I00_I99
# 1         10.256250                     0          O0803              O00_O99
# 2          8.612500                     0           G939              G00_G99
# 3          1.702083                     0         S32010              S00_T88
# 4         12.466666                     0           G952              G00_G99
# ...             ...                   ...            ...                  ...
# 143318     0.125000                     0          Z5181              Z00_Z99
# 143319    12.709028                     6           C569              C00_D49
# 143320    22.671528                     0           Z515              Z00_Z99
# 143321    11.992361                     1           Z515              Z00_Z99
# 143322     8.523611                     6           I500              I00_I99
#
#        admit_via_ambulance triage_level
# 0             no_ambulance     emergent
# 1             no_ambulance     emergent
# 2             no_ambulance     emergent
# 3                   ground     emergent
# 4             no_ambulance       urgent
# ...                    ...          ...
# 143318             no_info      no_info
# 143319              ground       urgent
# 143320        no_ambulance     emergent
# 143321              ground       urgent
# 143322        no_ambulance     emergent
#
# [143323 rows x 16 columns]

# %%
cohort[OUTCOME_DEATH].sum() / len(cohort)
# Out:
# 0.10419123239117238

# %%
events
# Out:
#           encounter_id              event_name event_value event_value_unit  \
# 0             15320930  Mean Cell Volume (MCV)                           fL
# 1             15320930  Mean Cell Volume (MCV)                           fL
# 2             15320930  Mean Cell Volume (MCV)                           fL
# 3             15320930  Mean Cell Volume (MCV)                           fL
# 4             15320930  Mean Cell Volume (MCV)                           fL
# ...                ...                     ...         ...              ...
# 17502598      14802293   unmapped_intervention           1              NaN
# 17502599      14777944   unmapped_intervention           1              NaN
# 17502600      14531456   unmapped_intervention           1              NaN
# 17502601      14974045   unmapped_intervention           1              NaN
# 17502602      14974045   unmapped_intervention           1              NaN
#
#              event_timestamp event_category
# 0        2017-11-07 06:00:00           labs
# 1        2017-11-07 20:36:00           labs
# 2        2017-11-08 10:00:00           labs
# 3        2017-11-27 06:00:00           labs
# 4        2017-12-12 06:00:00           labs
# ...                      ...            ...
# 17502598 2015-03-25 00:00:00  interventions
# 17502599 2015-03-27 00:00:00  interventions
# 17502600 2015-03-30 00:00:00  interventions
# 17502601 2014-05-29 00:00:00  interventions
# 17502602 2014-05-29 00:00:00  interventions
#
# [17502603 rows x 6 columns]

# %%
# Intersect over encounter IDs to get only those encounters common to both
cohort, events = intersect_datasets([cohort, events], ENCOUNTER_ID)

# %%
save_dataframe(events, join(QUERIED_DIR, "batch_0000.parquet"))
# Out:
# 2022-11-08 13:16:27,570 INFO cyclops.utils.file - Saving dataframe to /mnt/nfs/project/delirium/drift_exp/OCT-18-2022/gemini/mortality_decompensation/./data/0-queried/batch_0000.parquet
# '/mnt/nfs/project/delirium/drift_exp/OCT-18-2022/gemini/mortality_decompensation/./data/0-queried/batch_0000.parquet'

# %% [markdown]
# # Clean / Preprocess

# %%
death_events = cohort[cohort[OUTCOME_DEATH] == True]  # noqa: E712
death_events = death_events[[ENCOUNTER_ID, DISCHARGE_TIMESTAMP]]
death_events = death_events.rename({DISCHARGE_TIMESTAMP: TARGET_TIMESTAMP}, axis=1)
cohort = pd.merge(cohort, death_events, on=ENCOUNTER_ID, how="left")
cohort
# Out:
#         encounter_id     admit_timestamp discharge_timestamp  age sex  \
# 0           11100040 2018-07-03 21:36:00 2018-08-03 09:35:00   84   M
# 1           11100041 2016-12-26 18:21:00 2016-12-27 11:00:00   76   F
# 2           11100072 2016-08-13 15:20:00 2016-08-16 16:45:00   72   F
# 3           11100095 2015-12-20 18:36:00 2015-12-30 10:25:00   84   M
# 4           11100097 2019-05-23 06:09:00 2019-05-28 13:07:00   65   M
# ...              ...                 ...                 ...  ...  ..
# 143044      15999822 2012-04-09 21:44:00 2012-04-10 17:21:00   61   M
# 143045      15999864 2018-04-30 20:30:00 2018-05-06 12:46:00   58   F
# 143046      15999918 2019-09-18 05:59:00 2019-09-20 14:45:00   68   F
# 143047      15999943 2015-01-17 08:17:00 2015-01-23 11:33:00   78   F
# 143048      15999969 2015-02-17 19:40:00 2015-02-26 11:37:00   76   F
#
#        hospital_id  outcome_death                  readmission  \
# 0              SMH          False           planned_from_acute
# 1              SMH          False                 new_to_acute
# 2              SMH          False                 new_to_acute
# 3              SMH          False  unplanned_8_to_28_day_acute
# 4              SMH          False           planned_from_acute
# ...            ...            ...                          ...
# 143044        THPM          False                 new_to_acute
# 143045        THPC          False                 new_to_acute
# 143046        THPM          False                 new_to_acute
# 143047        THPM          False                         nota
# 143048        THPM          False                 new_to_acute
#
#         from_nursing_home_mapped  from_acute_care_institution_mapped  \
# 0                          False                               False
# 1                          False                               False
# 2                          False                               False
# 3                          False                               False
# 4                           True                               False
# ...                          ...                                 ...
# 143044                     False                               False
# 143045                     False                               False
# 143046                     False                               False
# 143047                     False                               False
# 143048                     False                                True
#
#         los_derived  prev_encounter_count diagnosis_code diagnosis_trajectory  \
# 0         30.499306                     1           G459              G00_G99
# 1          0.693750                     0            R55              R00_R99
# 2          3.059028                     0           J441              J00_J99
# 3          9.659028                     0           T826              S00_T88
# 4          5.290278                     7           N390              N00_N99
# ...             ...                   ...            ...                  ...
# 143044     0.817361                     0           I635              I00_I99
# 143045     5.677778                     0           L032              L00_L99
# 143046     2.365278                     0            R55              R00_R99
# 143047     6.136111                     0            J09              J00_J99
# 143048     8.664583                     0           I634              I00_I99
#
#        admit_via_ambulance   triage_level deathtime
# 0                   ground  resuscitation       NaT
# 1                   ground       emergent       NaT
# 2             no_ambulance       emergent       NaT
# 3             no_ambulance       emergent       NaT
# 4                   ground       emergent       NaT
# ...                    ...            ...       ...
# 143044              ground       emergent       NaT
# 143045        no_ambulance       emergent       NaT
# 143046              ground       emergent       NaT
# 143047              ground         urgent       NaT
# 143048             no_info        no_info       NaT
#
# [143049 rows x 17 columns]

# %%
save_dataframe(cohort, ENCOUNTERS_FILE)
# Out:
# 2022-11-08 13:21:01,087 INFO cyclops.utils.file - Saving dataframe to /mnt/nfs/project/delirium/drift_exp/OCT-18-2022/gemini/mortality_decompensation/./data/encounters.parquet
# '/mnt/nfs/project/delirium/drift_exp/OCT-18-2022/gemini/mortality_decompensation/./data/encounters.parquet'

# %%
# Normalize names and string values
events[EVENT_NAME] = normalize_names(events[EVENT_NAME])
events[EVENT_VALUE] = normalize_values(events[EVENT_VALUE])

# Convert values to numeric, dropping those which can't be converted
events[EVENT_VALUE] = pd.to_numeric(events[EVENT_VALUE], errors="coerce")
print("Length before:", len(events))
events = events[~events[EVENT_VALUE].isna()]
print("Length after:", len(events))
events
# Out:
# Length before: 17502603
# Length after: 17029291
#           encounter_id             event_name  event_value event_value_unit  \
# 17371788      11100040  unmapped_intervention          1.0              NaN
# 15174588      11100040  glucose point of care         10.9           mmol/L
# 15174587      11100040  glucose point of care         10.9           mmol/L
# 15174586      11100040  glucose point of care         10.8           mmol/L
# 15174585      11100040  glucose point of care         10.7           mmol/L
# ...                ...                    ...          ...              ...
# 66069         15999969                albumin         28.0              g/L
# 66068         15999969                   aptt         26.5              SEC
# 66067         15999969                   aptt         24.8              SEC
# 66076         15999969         arterial paco2         31.0             MMHG
# 65953         15999969       mean cell volume         94.5               fL
#
#              event_timestamp event_category
# 17371788 2018-07-04 00:00:00  interventions
# 15174588 2018-07-11 21:08:00           labs
# 15174587 2018-07-04 21:18:00           labs
# 15174586 2018-07-06 12:25:00           labs
# 15174585 2018-07-18 17:15:00           labs
# ...                      ...            ...
# 66069    2015-02-20 03:50:00           labs
# 66068    2015-02-17 22:00:00           labs
# 66067    2015-02-19 05:50:00           labs
# 66076    2015-02-19 05:50:00           labs
# 65953    2015-02-19 05:50:00           labs
#
# [17029291 rows x 6 columns]

# %%
save_dataframe(events, join(CLEANED_DIR, "batch_0000.parquet"))
# Out:
# 2022-11-08 13:26:45,574 INFO cyclops.utils.file - Saving dataframe to /mnt/nfs/project/delirium/drift_exp/OCT-18-2022/gemini/mortality_decompensation/./data/1-cleaned/batch_0000.parquet
# '/mnt/nfs/project/delirium/drift_exp/OCT-18-2022/gemini/mortality_decompensation/./data/1-cleaned/batch_0000.parquet'
